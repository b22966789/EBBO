# %% [markdown]
# <a href="https://colab.research.google.com/github/b22966789/EBBO/blob/master/gbackground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
from math import sqrt

# %%
# 使用 OpenCV 讀取圖檔
img_bgr = cv2.imread('img2.jpg')

# 將 BGR 圖片轉為 RGB 圖片
img_rgb = img_bgr[:,:,::-1]
plt.imshow(img_rgb)
plt.show()

# %%
back = cv2.imread('back2.jpg')
backrgb = back[:,:,::-1]
plt.imshow(backrgb)
plt.show()

# %%
def change_background(image, new_background, replace_color):
  height, width, channels = image.shape
  for i in range(height):
    for j in range(width):
      if color_distance(image[i][j], replace_color) < 110:
        image[i][j]=new_background[i][j]

  return None

# %%
def color_distance(color1, color2):
  a = (color1[0]-color2[0])**2
  b = (color1[1]-color2[1])**2
  c = (color1[2]-color2[2])**2
  dist = sqrt(a+b+c)
  return dist

# %%
replace_color=[0, 177, 64]
change_background(img_rgb, backrgb, replace_color)

# %%
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb = img_rgb[:,:,::-1]
cv2.imwrite('output1.jpg', img_rgb)
# Out:
# True
